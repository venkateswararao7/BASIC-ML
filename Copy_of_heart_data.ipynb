# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateswararao7/BASIC-ML/blob/main/Copy_of_heart_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data set that we taken is having the 13 coloums(without the index coloum, it as no specific role playing the data )and data sample of 300 .it does not any values also.

# %% [markdown]
# ## *machine learning about the clinical data*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
print("set up completed")
# Out:
# set up completed

# %% [markdown]
# importing the necessary libraries present in python

# %%
my_data=pd.read_csv('/content/heart.csv')
print('storing of csv file into my_data is completed')
# Out:
# storing of csv file into my_data is completed

# %% [markdown]
# A heart attack occurs when the flow of blood to the heart is blocked. The blockage is most often a buildup of fat, cholesterol and other substances, which form a plaque in the arteries that feed the heart (coronary arteries).

# %% [markdown]
# **printing the starting 5 coloums of the given data(heart.csv)**

# %%
my_data.head()#it will print the starting 5 coloums of the data
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %% [markdown]
# printing the last 5 coloums of the given heart.csv

# %%
my_data.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 294  62.0        0                        61  ...        1   270            0
# 295  55.0        0                      1820  ...        0   271            0
# 296  45.0        0                      2060  ...        0   278            0
# 297  45.0        0                      2413  ...        1   280            0
# 298  50.0        0                       196  ...        1   285            0
#
# [5 rows x 13 columns]

# %%
my_data.mean()
# Out:
# age                             60.0
# anaemia                          0.0
# creatinine_phosphokinase       250.0
# diabetes                         0.0
# ejection_fraction               38.0
# high_blood_pressure              0.0
# platelets                   262000.0
# serum_creatinine                 1.1
# serum_sodium                   137.0
# sex                              1.0
# smoking                          0.0
# time                           115.0
# DEATH_EVENT                      0.0
# dtype: float64

# %%
my_data.median()
# Out:
# age                             60.0
# anaemia                          0.0
# creatinine_phosphokinase       250.0
# diabetes                         0.0
# ejection_fraction               38.0
# high_blood_pressure              0.0
# platelets                   262000.0
# serum_creatinine                 1.1
# serum_sodium                   137.0
# sex                              1.0
# smoking                          0.0
# time                           115.0
# DEATH_EVENT                      0.0
# dtype: float64

# %%
my_data.mode()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  60.0      0.0                     582.0  ...      0.0   187          0.0
# 1   NaN      NaN                       NaN  ...      NaN   250          NaN
#
# [2 rows x 13 columns]

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
my_data['age'].unique()
# Out:
# array([75.   , 55.   , 65.   , 50.   , 90.   , 60.   , 80.   , 62.   ,
#        45.   , 49.   , 82.   , 87.   , 70.   , 48.   , 68.   , 53.   ,
#        95.   , 58.   , 94.   , 85.   , 69.   , 72.   , 51.   , 57.   ,
#        42.   , 41.   , 67.   , 79.   , 59.   , 44.   , 63.   , 86.   ,
#        66.   , 43.   , 46.   , 61.   , 81.   , 52.   , 64.   , 40.   ,
#        60.667, 73.   , 77.   , 78.   , 54.   , 47.   , 56.   ])

# %% [markdown]
# **after  running of thise code we understand that thise is no null values present in data set. afterexcept platelets and serum_creartinine are float type ,remaining all are int type.the minimum age of the person is 40**

# %%
plt.figure(figsize=(20,15))
sns.swarmplot(x=my_data['age'],y=my_data['serum_sodium'])

# %% [markdown]
# from the swarmplot we understand that the persons who are above the above the 40 years are facing the heart problems , most of thise people who are above the 50 are mostly facing the death

# %%
plt.figure(figsize=(15,9))
plt.title("the boxplot b/w creatine_phosphokinase and DEATH_EVENT ")
sns.boxplot(x= my_data['DEATH_EVENT'] ,y=my_data['creatinine_phosphokinase'])

# %% [markdown]
# Creatine kinase or creatine phosphokinase is an enzyme chiefly found in the brain, skeletal muscles, and heart. An elevated level of creatine kinase is seen in heart attacks, when the heart muscle is damaged, or in conditions that produce damage to the skeletal muscles or brain.
# when you observe the boxplot that is present in the above ,we can understand that the people who have the elevated level of crearine kinese is seen in heart attacks ,due to thise majority of people are caused to die.

# %%
plt.figure(figsize=(2,1))
plt.title('no of male and females DEATHS due to heart problems')
sns.swarmplot(x=my_data['sex'],y=my_data['DEATH_EVENT'])

# %% [markdown]
# gender is not a factor that effect the heart related problems,as we observe the swarmplot that tells us nearly there is differance in deaths of male and female but in general gender is not a important ,deaths are caused due to other factors.

# %% [markdown]
# nearly the no of males and females are facing the heart *problems*

# %%
plt.figure(figsize=(16,8))
plt.title("swarmmplot b/w ejecton_fraction and high_blood_pressure")
sns.swarmplot(x=my_data['high_blood_pressure'],y=my_data['ejection_fraction'])

# %% [markdown]
# High blood pressure can also cause ischemic heart disease. This means that the heart muscle isn't getting enough blood. Ischemic heart disease is usually the result of atherosclerosis or hardening of the arteries ( coronary artery disease ), which impedes blood flow to the heart. Symptoms of ischemic heart disease may include.
# High blood pressure can also cause ischemic heart disease. This means that the heart muscle isn't getting enough blood. Ischemic heart disease is usually the result of atherosclerosis or hardening of the arteries ( coronary artery disease ), which impedes blood flow to the heart. Symptoms of ischemic heart disease may include.
# from the above swarmplot we observe that people who are having the high_blood_pressure and high ejection are majorly facing the heart related diseases.

# %%
plt.figure(figsize=(14,8))
plt.title("heart_failure_clinic_records")
sns.lineplot(data=my_data)
