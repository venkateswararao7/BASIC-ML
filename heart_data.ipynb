# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateswararao7/BASIC-ML/blob/main/heart_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# importing the necessary libraries present in python

# %%
my_data=pd.read_csv('/heart.csv')

# %% [markdown]
# **printing the starting 5 coloums of the given data(heart.csv)**

# %%
my_data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %% [markdown]
# printing the last 5 coloums of the given heart.csv

# %%
my_data.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 294  62.0        0                        61  ...        1   270            0
# 295  55.0        0                      1820  ...        0   271            0
# 296  45.0        0                      2060  ...        0   278            0
# 297  45.0        0                      2413  ...        1   280            0
# 298  50.0        0                       196  ...        1   285            0
#
# [5 rows x 13 columns]

# %%
my_data.mean()
# Out:
# age                             60.0
# anaemia                          0.0
# creatinine_phosphokinase       250.0
# diabetes                         0.0
# ejection_fraction               38.0
# high_blood_pressure              0.0
# platelets                   262000.0
# serum_creatinine                 1.1
# serum_sodium                   137.0
# sex                              1.0
# smoking                          0.0
# time                           115.0
# DEATH_EVENT                      0.0
# dtype: float64

# %%
my_data.median()
# Out:
# age                             60.0
# anaemia                          0.0
# creatinine_phosphokinase       250.0
# diabetes                         0.0
# ejection_fraction               38.0
# high_blood_pressure              0.0
# platelets                   262000.0
# serum_creatinine                 1.1
# serum_sodium                   137.0
# sex                              1.0
# smoking                          0.0
# time                           115.0
# DEATH_EVENT                      0.0
# dtype: float64

# %%
my_data.mode()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  60.0      0.0                     582.0  ...      0.0   187          0.0
# 1   NaN      NaN                       NaN  ...      NaN   250          NaN
#
# [2 rows x 13 columns]

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# **after  running of thise code we understand that thise is no null values present in data set. afterexcept platelets and serum_creartinine are float type ,remaining all are int type**

# %%
plt.figure(figsize=(14,8))
plt.title("heart_failure_clinic_records")
sns.lineplot(data=my_data)
