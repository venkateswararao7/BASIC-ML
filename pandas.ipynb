# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateswararao7/BASIC-ML/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
mydataset={'cars':['volva','ford'],'price':[1,2]}
df=pd.DataFrame(mydataset)
print(pd.Series(mydataset))
print(df)
# Out:
# cars     [volva, ford]
# price           [1, 2]
# dtype: object
#     cars  price
# 0  volva      1
# 1   ford      2

# %%
print(pd.__version__)
# Out:
# 2.0.3

# %%
array=[1,2,3,4]
print(pd.Series(array,index=['x','y','z','A']))
# Out:
# x    1
# y    2
# z    3
# A    4
# dtype: int64

# %%
data=pd.read_csv("/content/TeluguSameFeeling.csv");
print(data.to_string())
# Out:
#                           Emotion Unnamed: 1                                  Song Name Old or New                           Movie Name
# 0                           Anger        NaN                            Lechindi Nidira       Old                       Gundaamma Katha
# 1                           Anger        NaN                     Ragilindhi Viplaavagni       Old                Alluri Seetharama Raju
# 2                           Anger        NaN                               Nenu Puttanu       Old                            Prem Nagar
# 3                           Anger        NaN                        Teluguveera Levaraa       Old                Alluri Seetharama Raju
# 4                           Anger        NaN                                Ragulutondi       Old                                Khaidi
# 5                           Anger        NaN                      Narudu Bratuku Natana       Old                        Subhasankalpam
# ...

# %%
data.head()
# Out:
#   Emotion Unnamed: 1               Song Name Old or New  \
# 0   Anger        NaN         Lechindi Nidira       Old
# 1   Anger        NaN  Ragilindhi Viplaavagni       Old
# 2   Anger        NaN            Nenu Puttanu       Old
# 3   Anger        NaN     Teluguveera Levaraa       Old
# 4   Anger        NaN             Ragulutondi       Old
#
#                Movie Name
# 0         Gundaamma Katha
# 1  Alluri Seetharama Raju
# 2              Prem Nagar
# 3  Alluri Seetharama Raju
# 4                  Khaidi

# %%
print(data.loc[1])
# Out:
# Emotion                        Anger
# Unnamed: 1                       NaN
# Song Name     Ragilindhi Viplaavagni
# Old or New                      Old
# Movie Name    Alluri Seetharama Raju
# Name: 1, dtype: object

# %%
data = data.drop(columns=['Unnamed: 1'])

# %%
data.head()
# Out:
#   Emotion               Song Name Old or New              Movie Name
# 0   Anger         Lechindi Nidira       Old          Gundaamma Katha
# 1   Anger  Ragilindhi Viplaavagni       Old   Alluri Seetharama Raju
# 2   Anger            Nenu Puttanu       Old               Prem Nagar
# 3   Anger     Teluguveera Levaraa       Old   Alluri Seetharama Raju
# 4   Anger             Ragulutondi       Old                   Khaidi

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emotion     549 non-null    object
#  1   Song Name   462 non-null    object
#  2   Old or New  549 non-null    object
#  3   Movie Name  462 non-null    object
# dtypes: object(4)
# memory usage: 17.3+ KB

# %%
data.shape
# Out:
# (549, 4)

# %%
data.dropna()
# Out:
#                   Emotion               Song Name Old or New  \
# 0                   Anger         Lechindi Nidira       Old
# 1                   Anger  Ragilindhi Viplaavagni       Old
# 2                   Anger            Nenu Puttanu       Old
# 3                   Anger     Teluguveera Levaraa       Old
# 4                   Anger             Ragulutondi       Old
# ..                    ...                     ...        ...
# 544  Daughter's Sentiment         Chinnari Thalli        New
# 545  Daughter's Sentiment         Laalijo Laalijo        New
# 546  Daughter's Sentiment             Gaaju Bomma        New
# 547  Daughter's Sentiment          Laali Laali Jo        New
# 548  Daughter's Sentiment                Chinnari        New
#
#                  Movie Name
# 0           Gundaamma Katha
# 1    Alluri Seetharama Raju
# 2                Prem Nagar
# 3    Alluri Seetharama Raju
# 4                    Khaidi
# ..                      ...
# 544                Viswasam
# ...

# %%
data.shape
# Out:
# (549, 4)

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# Length: 549, dtype: bool

# %%
data.drop_duplicates(inplace=True)

# %%
import matplotlib.pyplot as plt
data.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-47ac7e1ab64c> in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 data.plot()
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     973                     data.columns = label_name
#     974
# --> 975         return plot_backend.plot(data, kind=kind, **kwargs)
#     976
#     977     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...
